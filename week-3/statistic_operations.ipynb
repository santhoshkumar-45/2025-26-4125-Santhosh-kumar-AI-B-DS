# %% [markdown]
# <a href="https://colab.research.google.com/github/santhoshkumar-45/2025-26-4125-Santhosh-kumar-AI-B-DS/blob/main/week-3/statistic_operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Create DataFrame
data = {'values': [10, 12, 15, 18, 20, 22, 25, 30, 35, 40]}
df = pd.DataFrame(data)

print("Dataset:")
print(df)

# a) Mean, Median, Mode
print("\nMean:", df['values'].mean())
print("Median:", df['values'].median())
print("Mode:\n", df['values'].mode())

# b) Standard Deviation
print("\nStandard Deviation:", df['values'].std())

# c) Variance
print("Variance:", df['values'].var())

# d) Kurtosis
print("Kurtosis:", df['values'].kurt())

# e) Skewness
print("Skewness:", df['values'].skew())
# Out:
# Dataset:
#    values
# 0      10
# 1      12
# 2      15
# 3      18
# 4      20
# 5      22
# 6      25
# 7      30
# 8      35
# 9      40
#
# Mean: 22.7
# Median: 21.0
# Mode:
#  0    10
# 1    12
# 2    15
# 3    18
# 4    20
# 5    22
# 6    25
# 7    30
# 8    35
# 9    40
# Name: values, dtype: int64
#
# Standard Deviation: 9.855060741681008
# Variance: 97.1222222222222
# Kurtosis: -0.6716875282155641
# Skewness: 0.5203493641920655
