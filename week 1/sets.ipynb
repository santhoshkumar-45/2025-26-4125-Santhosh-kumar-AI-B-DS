# %% [markdown]
# <a href="https://colab.research.google.com/github/santhoshkumar-45/2025-26-4125-Santhosh-kumar-AI-B-DS/blob/main/sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = {1, 2, 3, 4, 5}
print(numbers)
# Out:
# {1, 2, 3, 4, 5}

# %%
fruits = {"apple", "banana"}
fruits.add("cherry")
print(fruits)
# Out:
# {'apple', 'banana', 'cherry'}

# %%
cities = {"Paris", "London", "Tokyo"}

if "London" in cities:
    print("London is in the set")
# Out:
# London is in the set
