# %% [markdown]
# <a href="https://colab.research.google.com/github/santhoshkumar-45/2025-26-4125-Santhosh-kumar-AI-B-DS/blob/main/Dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student = {"name": "Alice", "age": 20, "marks": 85}
print(student)
# Out:
# {'name': 'Alice', 'age': 20, 'marks': 85}

# %%
student = {"name": "Alice", "age": 20, "marks": 85}
print(student["name"])
print(student["marks"])
# Out:
# Alice
# 85

# %%
student = {"name": "Alice", "age": 20, "marks": 85}
student.pop("marks")
print(student)
# Out:
# {'name': 'Alice', 'age': 20}

# %%
students = {
    "student1": {"name": "Alice", "age": 20},
    "student2": {"name": "Bob", "age": 21}
}

print(students["student1"]["name"])
# Out:
# Alice
