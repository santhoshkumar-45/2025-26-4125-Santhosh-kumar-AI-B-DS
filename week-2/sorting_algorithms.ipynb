# %% [markdown]
# <a href="https://colab.research.google.com/github/santhoshkumar-45/2025-26-4125-Santhosh-kumar-AI-B-DS/blob/main/week-2/sorting_algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# bubble sort
n = int(input("Enter number of elements: "))

arr = []

for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))

print("\nOriginal array:", arr)

# Bubble sort
for i in range(n-1):
    for j in range(n-1-i):
        if arr[j] > arr[j+1]:
            arr[j], arr[j+1] = arr[j+1], arr[j]

print("Sorted array:", arr)
# Out:
# Enter number of elements: 3
# Enter element 1: 4
# Enter element 2: 5
# Enter element 3: 6
#
# Original array: [4, 5, 6]
# Sorted array: [4, 5, 6]

# %%
# Selection sort
n = int(input("enter number of elements:"))

arr = []

for i in range(n):
    arr.append(int(input(f"enter element {i+1}:")))

print("\n Original array:", arr)

# selection sort logic
for i in range(n-1):
    min_index = i
    for j in range(i+1, n):
        if arr[j] < arr[min_index]:
            min_index = j

    # swap found min element with first element
    arr[i], arr[min_index] = arr[min_index], arr[i]

print("sorted array:", arr)
# Out:
# enter number of elements:3
# enter element 1:4
# enter element 2:5
# enter element 3:6
#
#  Original array: [4, 5, 6]
# sorted array: [4, 5, 6]

# %%
# Sample data
arr = [64, 25, 12, 22, 11]

print("Original Array:", arr)
#Insertion Sort
def insertion_sort(lst):
    for i in range(1, len(lst)):
        key = lst[i]
        j = i - 1
        while j >= 0 and key < lst[j]:
            lst[j+1] = lst[j]
            j -= 1
        lst[j+1] = key
    return lst

insertion_sorted = insertion_sort(arr.copy())
print("Insertion Sorted Array:", insertion_sorted)
# Out:
# Original Array: [64, 25, 12, 22, 11]
# Insertion Sorted Array: [11, 12, 22, 25, 64]
