# %% [markdown]
# <a href="https://colab.research.google.com/github/santhoshkumar-45/2025-26-4125-Santhosh-kumar-AI-B-DS/blob/main/week-4/Replace_with_Mean_of_the_column.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Example DataFrame
data = {
    'A': [1, 2, np.nan, 4, 5],
    'B': [5, np.nan, 7, 8, np.nan]
}

df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)

# Replace missing values with column mean
df_filled = df.fillna(df.mean())

print("\nDataFrame after replacing NaN with column mean:")
print(df_filled)
# Out:
# Original DataFrame:
#      A    B
# 0  1.0  5.0
# 1  2.0  NaN
# 2  NaN  7.0
# 3  4.0  8.0
# 4  5.0  NaN
#
# DataFrame after replacing NaN with column mean:
#      A         B
# 0  1.0  5.000000
# 1  2.0  6.666667
# 2  3.0  7.000000
# 3  4.0  8.000000
# 4  5.0  6.666667
